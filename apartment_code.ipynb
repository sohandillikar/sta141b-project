# %%
##### Places (New) API Stuff #####
import pandas as pd
import googlemaps as gm

# API Key + initializing other variables
key = 'AIzaSyBmsneyKTKlU4jONx2H_kolK0Ht2lhpDoE'
gmaps = gm.Client(key = key, timeout = 1, queries_per_second= 50)

# Sample data
coords = (38.548331297891, -121.75986861974903) # Sycamore Lane Apartments
radius = 5000 # in meters ; ~3 miles

# %%
##### Apartments in Davis #####
# Initalizing variables
center = (38.5495321428149, -121.74007196158973) # coordinates for Davis Co-Op; approximate center of Davis
radius = 9656 # ~6 miles

### Pulling apartment complexes ###
complexes = gmaps.places(query = 'apartment complexes', location = center, radius = radius, type = 'apartment_complex')
n = len(complexes['results']) - 1

# Pulling names
name1 = []
for i in range(n):
    name1.append(complexes['results'][i]['name'])

# Pulling coordinates
coord1 = []
for i in range(n):
    coord1.append((complexes['results'][i]['geometry']['location']['lat'], complexes['results'][i]['geometry']['location']['lng']))

### Pulling apartment buildings ###
buildings = gmaps.places(query = 'apartment buildings', location = center, radius = radius, type = 'apartment_building')
m = len(buildings['results']) - 1

# Pulling names
name2 = []
for i in range(m):
    name2.append(buildings['results'][i]['name'])

# Pulling coordinates
coord2 = []
for i in range(m):
    coord2.append((buildings['results'][i]['geometry']['location']['lat'], buildings['results'][i]['geometry']['location']['lng']))

# %%
##### Merging & cleaning #####
# Merging complexes and buildings
names = []
names = name1 + name2

coordss = []
coordss = coord1 + coord2

# Cleaning data
names = list(dict.fromkeys(names)) # removing duplicates
coordss = list(dict.fromkeys(coordss))  # removing duplicates

apts_in_davis = pd.DataFrame({"Apartment Names" : names, "Coordinates" : coordss}) 
apts_in_davis = apts_in_davis.sort_values(by = "Apartment Names").reset_index(drop=True)
